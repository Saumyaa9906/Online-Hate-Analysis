# %%
import numpy as np
import pandas as pd
import json

# %%
users1 = pd.read_csv('snsusers_users.csv')
#users1.head()
print(users1.shape)
# Out:
# (19, 13)

# %%
users2 = pd.read_csv('snshashtags_users.csv')
#users2.head()
users2.shape
# Out:
# (1130, 13)

# %%
#merge users
users = pd.concat([users1,users2])
users.head()
# Out:
#      username         displayname               userId  \
# 0   btfmrises                   ً  1225094973948878853
# 1  bisexualjb             tristan   702934687551983616
# 2  joohwangsi    save palestine🇵🇸  1368643588054118400
# 3    icnsgore       ateez disband  1393369710717280263
# 4    bbarajey  loona flop disband  1395442212062863366
#
#                                       rawDescription  verified  \
# 0                               i am not a troll btw     False
# 1  what the actual fuck, oh my gosh how insecure ...     False
# 2                              positive vibes only❤️     False
# 3             no staneo a nadie, no rompan las bolas     False
# 4                                                ...     False
#
#                      created  followersCount  friendsCount  statusesCount  \
# 0  2020-02-05T16:33:04+00:00              17            14            329
# 1  2016-02-25T19:14:24+00:00             171            40             81
# ...

# %%
users.shape
# Out:
# (1149, 13)

# %%
#drop duplicates, clean
users = pd.DataFrame(users)
users.drop_duplicates(subset=['userId'], inplace=True)
users.head()
users.shape
# Out:
# (1141, 13)

# %%
#users.to_csv('dataset_users.csv',index = False)

# %%
tweets1 = pd.read_csv('snsusers_tweets.csv')
print(tweets1.shape)
tweets2 = pd.read_csv('snshashtags_tweets.csv')
print(tweets2.shape)
# Out:
# (7134, 12)
# (3380, 12)

# %%
#merge tweet data
tweets = pd.concat([tweets1,tweets2])
print(tweets.shape)

#drop duplicates, clean
tweets = pd.DataFrame(tweets)
tweets.drop_duplicates(subset=['tweetId'], inplace=True)
print(tweets.shape)
# Out:
# (10514, 12)
# (10490, 12)

# %%
tweets.head()
# Out:
#                         date  \
# 0  2021-05-29 00:53:33+00:00
# 1  2021-05-28 23:54:38+00:00
# 2  2021-05-28 22:06:12+00:00
# 3  2021-05-28 22:03:53+00:00
# 4  2021-05-28 22:02:39+00:00
#
#                                      renderedContent              tweetId  \
# 0                  @TETEPROTECT0R he’s jinjja uwu~~😞  1398442352868462596
# 1  @J4MAlSVU_ @yeoyxy @vminkookurz yes coz even s...  1398427525844549633
# 2   @jnkstigmaa chan outsold https://t.co/A5jMzyqVvZ  1398400240173076481
# 3  @jnkstigmaa EXCUSE MEEEEE&amp;:):&amp;):£: i a...  1398399655533236232
# 4     @jnkstigmaa gottem mad https://t.co/RncbakBowH  1398399345356165122
#
#                 userId  replyCount  retweetCount  likeCount  quoteCount  \
# 0  1225094973948878853           1             0          1           0
# 1  1225094973948878853           5             2          2          11
# 2  1225094973948878853           1             0          0           1
# ...

# %%
#tweets.to_csv('dataset_tweets.csv',index = False)

# %%
tweets[['tweetId','lang']].groupby('lang').count().sort_values(by = ['tweetId'], ascending=False)
# Out:
#                     tweetId
# lang
# English                7284
# Spanish; Castilian     1220
# Korean                  404
# Indonesian              278
# Tagalog                 120
# Romanian, Moldavan      117
# Estonian                 74
# Polish                   56
# Portuguese               53
# Haitian                  50
# Finnish                  39
# French                   37
# Danish                   33
# Dutch                    18
# Italian                  17
# German                   14
# Hungarian                13
# Swedish                  12
# Czech                    11
# Basque                    8
# Lithuanian                7
# Norwegian                 7
# Welsh                     6
# Catalan; Valencian        6
# Slovene                   5
# Turkish                   5
# Icelandic                 4
# Thai                      4
# Vietnamese                4
# Latvian                   3
# Hindi                     2
# Russian                   1
# ...
