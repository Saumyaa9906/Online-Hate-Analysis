# %%
import os
import pandas as pd
import numpy as np
import glob

# %%
from pandas.io.json import json_normalize
import warnings

warnings.filterwarnings("ignore")

# %%
flag = 1
for file in glob.glob("*.json"):
    df = pd.read_json(file, lines = True)
    if flag == 1:
        cols = df.columns
        df_users = pd.DataFrame(columns = cols)
        flag = 0
    else:
        df_users = pd.concat([df_users,df])
# Out:
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here
# Here

# %%
df_users.iloc[60:70]
# Out:
#                              _type  \
# 8   snscrape.modules.twitter.Tweet
# 9   snscrape.modules.twitter.Tweet
# 10  snscrape.modules.twitter.Tweet
# 11  snscrape.modules.twitter.Tweet
# 12  snscrape.modules.twitter.Tweet
# 13  snscrape.modules.twitter.Tweet
# 14  snscrape.modules.twitter.Tweet
# 15  snscrape.modules.twitter.Tweet
# 16  snscrape.modules.twitter.Tweet
# 17  snscrape.modules.twitter.Tweet
#
#                                                   url  \
# 8   https://twitter.com/joohwangsi/status/13932299...
# 9   https://twitter.com/joohwangsi/status/13932180...
# 10  https://twitter.com/joohwangsi/status/13932177...
# 11  https://twitter.com/joohwangsi/status/13932071...
# 12  https://twitter.com/joohwangsi/status/13932065...
# 13  https://twitter.com/joohwangsi/status/13932060...
# 14  https://twitter.com/joohwangsi/status/13932053...
# 15  https://twitter.com/joohwangsi/status/13932041...
# 16  https://twitter.com/joohwangsi/status/13932039...
# 17  https://twitter.com/joohwangsi/status/13932038...
#
#                         date  \
# 8  2021-05-14 15:41:19+00:00
# 9  2021-05-14 14:54:00+00:00
# 10 2021-05-14 14:52:58+00:00
# 11 2021-05-14 14:10:46+00:00
# 12 2021-05-14 14:08:30+00:00
# 13 2021-05-14 14:06:14+00:00
# 14 2021-05-14 14:03:39+00:00
# 15 2021-05-14 13:58:46+00:00
# 16 2021-05-14 13:58:10+00:00
# 17 2021-05-14 13:57:36+00:00
#
#                                               content  \
# 8   @Happier222 @dariushours @chartdata @Olivia_Ro...
# 9                              @allkpop suga couldn’t
# 10  @rgnlouisa @allkpop they even fired u omg fuck...
# 11  @dojapallet @anoyeen @PopCrave that was edited...
# 12  that must be jungkook’s room!! https://t.co/Rz...
# 13  @jeonvxcal_ @h0emimi @chartdata @JAYBDEF___ at...
# 14  @jennieoutsoldz @Twitter bighit capitalism and...
# 15                       @seultrv @PopCrave is nayeon
# 16                  @aryxari @PopCrave especially bts
# 17  @dojapallet @anoyeen @PopCrave they’re ugly, t...
#
#                                       renderedContent                   id  \
# 8   @Happier222 @dariushours @chartdata @Olivia_Ro...  1393229948240875523
# 9                              @allkpop suga couldn’t  1393218042893463554
# 10  @rgnlouisa @allkpop they even fired u omg fuck...  1393217779575103490
# 11  @dojapallet @anoyeen @PopCrave that was edited...  1393207162021634048
# 12  that must be jungkook’s room!! twitter.com/pan...  1393206590107316232
# 13  @jeonvxcal_ @h0emimi @chartdata @JAYBDEF___ at...  1393206019409387525
# 14  @jennieoutsoldz @Twitter bighit capitalism and...  1393205371242614790
# 15                       @seultrv @PopCrave is nayeon  1393204139933405195
# 16                  @aryxari @PopCrave especially bts  1393203992486825987
# 17  @dojapallet @anoyeen @PopCrave they’re ugly, t...  1393203849268064262
#
#                                                  user  \
# 8   {'_type': 'snscrape.modules.twitter.User', 'us...
# 9   {'_type': 'snscrape.modules.twitter.User', 'us...
# 10  {'_type': 'snscrape.modules.twitter.User', 'us...
# 11  {'_type': 'snscrape.modules.twitter.User', 'us...
# 12  {'_type': 'snscrape.modules.twitter.User', 'us...
# 13  {'_type': 'snscrape.modules.twitter.User', 'us...
# 14  {'_type': 'snscrape.modules.twitter.User', 'us...
# 15  {'_type': 'snscrape.modules.twitter.User', 'us...
# 16  {'_type': 'snscrape.modules.twitter.User', 'us...
# 17  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                              outlinks  \
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12  [https://twitter.com/pannchoa/status/139320380...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
#
#                   tcooutlinks replyCount  ... lang  \
# 8                          []          1  ...   en
# 9                          []          1  ...   en
# 10                         []          0  ...   en
# 11                         []          0  ...   en
# 12  [https://t.co/Rzxf0uUzWe]          1  ...   en
# 13                         []          1  ...   en
# 14                         []          0  ...   en
# 15                         []          0  ...   tl
# 16                         []          3  ...   en
# 17                         []          2  ...   en
#
#                                                source  \
# 8   <a href="https://mobile.twitter.com" rel="nofo...
# 9   <a href="http://twitter.com/download/iphone" r...
# 10  <a href="http://twitter.com/download/iphone" r...
# 11  <a href="http://twitter.com/download/iphone" r...
# 12  <a href="http://twitter.com/download/iphone" r...
# 13  <a href="http://twitter.com/download/iphone" r...
# 14  <a href="http://twitter.com/download/iphone" r...
# 15  <a href="http://twitter.com/download/iphone" r...
# 16  <a href="http://twitter.com/download/iphone" r...
# 17  <a href="http://twitter.com/download/iphone" r...
#
#                              sourceUrl         sourceLabel  \
# 8           https://mobile.twitter.com     Twitter Web App
# 9   http://twitter.com/download/iphone  Twitter for iPhone
# 10  http://twitter.com/download/iphone  Twitter for iPhone
# 11  http://twitter.com/download/iphone  Twitter for iPhone
# 12  http://twitter.com/download/iphone  Twitter for iPhone
# 13  http://twitter.com/download/iphone  Twitter for iPhone
# 14  http://twitter.com/download/iphone  Twitter for iPhone
# 15  http://twitter.com/download/iphone  Twitter for iPhone
# 16  http://twitter.com/download/iphone  Twitter for iPhone
# 17  http://twitter.com/download/iphone  Twitter for iPhone
#
#                                                 media retweetedTweet  \
# 8                                                None            NaN
# 9                                                None            NaN
# 10                                               None            NaN
# 11  [{'_type': 'snscrape.modules.twitter.Photo', '...            NaN
# 12                                               None            NaN
# 13                                               None            NaN
# 14                                               None            NaN
# 15                                               None            NaN
# 16                                               None            NaN
# 17                                               None            NaN
#
#                                           quotedTweet  \
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12  {'_type': 'snscrape.modules.twitter.Tweet', 'u...
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
#
#                                        mentionedUsers coordinates place
# 8   [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 9   [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 10  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 11  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 12                                               None         NaN   NaN
# 13  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 14  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 15  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 16  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 17  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
#
# [10 rows x 24 columns]

# %%
#normalize user object
users = json_normalize(df['user'])
users.drop(['description', 'linkTcourl'], axis=1, inplace=True)
users.rename(columns={'id':'userId', 'url':'profileUrl'}, inplace=True)
users.head(2)
# Out:
#                            _type     username        displayname  \
# 0  snscrape.modules.twitter.User  BSupremacy7  BangtanSupremacy7
# 1  snscrape.modules.twitter.User      Vits_ex             Vits_♡
#
#                 userId                                     rawDescription  \
# 0  1398035707843821571  Only Army // OT7\nNo blinks, multis, exo-l, stays
# 1  1394323475213570054
#
#   descriptionUrls  verified                    created  followersCount  \
# 0              []     False  2021-05-27T21:57:49+00:00               0
# 1              []     False  2021-05-17T16:06:45+00:00              48
#
#    friendsCount  statusesCount  favouritesCount  listedCount  mediaCount  \
# 0             6              2                1            0           0
# 1           101              4                2            0           0
#
#   location  protected linkUrl  \
# 0               False    None
# 1               False    None
#
#                                      profileImageUrl  \
# 0  https://pbs.twimg.com/profile_images/139803582...
# 1  https://pbs.twimg.com/profile_images/139534387...
#
#                                     profileBannerUrl  \
# 0  https://pbs.twimg.com/profile_banners/13980357...
# 1  https://pbs.twimg.com/profile_banners/13943234...
#
#                         profileUrl
# 0  https://twitter.com/BSupremacy7
# 1      https://twitter.com/Vits_ex

# %%
#drop duplicates
users = pd.DataFrame(users)
users.drop_duplicates(subset=['userId'], inplace=True)
users.head(2)
# Out:
#                            _type     username        displayname  \
# 0  snscrape.modules.twitter.User  BSupremacy7  BangtanSupremacy7
# 1  snscrape.modules.twitter.User      Vits_ex             Vits_♡
#
#                 userId                                     rawDescription  \
# 0  1398035707843821571  Only Army // OT7\nNo blinks, multis, exo-l, stays
# 1  1394323475213570054
#
#   descriptionUrls  verified                    created  followersCount  \
# 0              []     False  2021-05-27T21:57:49+00:00               0
# 1              []     False  2021-05-17T16:06:45+00:00              48
#
#    friendsCount  statusesCount  favouritesCount  listedCount  mediaCount  \
# 0             6              2                1            0           0
# 1           101              4                2            0           0
#
#   location  protected linkUrl  \
# 0               False    None
# 1               False    None
#
#                                      profileImageUrl  \
# 0  https://pbs.twimg.com/profile_images/139803582...
# 1  https://pbs.twimg.com/profile_images/139534387...
#
#                                     profileBannerUrl  \
# 0  https://pbs.twimg.com/profile_banners/13980357...
# 1  https://pbs.twimg.com/profile_banners/13943234...
#
#                         profileUrl
# 0  https://twitter.com/BSupremacy7
# 1      https://twitter.com/Vits_ex

# %%
users.verified.unique()
# Out:
# array([False])

# %%
users.columns
# Out:
# Index(['_type', 'username', 'displayname', 'userId', 'rawDescription',
#        'descriptionUrls', 'verified', 'created', 'followersCount',
#        'friendsCount', 'statusesCount', 'favouritesCount', 'listedCount',
#        'mediaCount', 'location', 'protected', 'linkUrl', 'profileImageUrl',
#        'profileBannerUrl', 'profileUrl'],
#       dtype='object')

# %%
user_cols = ['username', 'displayname', 'userId','rawDescription','verified','created','followersCount',
       'friendsCount', 'statusesCount', 'favouritesCount', 'listedCount',
       'mediaCount', 'location']

# %%
tweet_users = users[user_cols]
tweet_users.head(5)
# Out:
#         username        displayname               userId  \
# 0    BSupremacy7  BangtanSupremacy7  1398035707843821571
# 1        Vits_ex             Vits_♡  1394323475213570054
# 2        NN1C0LE           yuri༊*·˚  1022820266462703617
# 3     jenlehyuck                  ً  1334459256947449856
# 6  IstanthemallK             남준LOML  1316582620289880064
#
#                                       rawDescription  verified  \
# 0  Only Army // OT7\nNo blinks, multis, exo-l, stays     False
# 1                                                        False
# 2                    17 ･☪·̩͙ cat art by: @ItsSelynn     False
# 3                                              media     False
# 6                Stan acc || Multifandom || LF Moots     False
#
#                      created  followersCount  friendsCount  statusesCount  \
# 0  2021-05-27T21:57:49+00:00               0             6              2
# 1  2021-05-17T16:06:45+00:00              48           101              4
# 2  2018-07-27T12:25:29+00:00             177           261           8836
# 3  2020-12-03T11:27:42+00:00             694             1          13487
# 6  2020-10-15T03:32:21+00:00               1            57            193
#
#    favouritesCount  listedCount  mediaCount     location
# 0                1            0           0
# 1                2            0           0
# 2            22081            1         279  she/he/they
# 3            13051           26         789
# 6              453            0          27

# %%
#add userid column
user_id = []
for user in df['user']:
    uid = user['id']
    user_id.append(uid)
df['userId'] = user_id

# %%
#clean
cols = ['date', 'renderedContent', 'id', 'userId', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount', 'media', 'retweetedTweet', 'quotedTweet', 'mentionedUsers', 'lang']
tweets = df[cols]
tweets.rename(columns={'id':'tweetId'}, inplace=True)
tweets.head(5)
# Out:
#                        date  \
# 0 2021-05-28 12:47:52+00:00
# 1 2021-05-28 12:38:58+00:00
# 2 2021-05-28 12:15:28+00:00
# 3 2021-05-28 09:50:23+00:00
# 4 2021-05-28 09:50:00+00:00
#
#                                      renderedContent              tweetId  \
# 0                             Hola pheos #nctdisband  1398259728938110977
# 1  #nctdisband Mano qual o problema de vocês pare...  1398257489376944146
# 2  #nctdisband look how fine johnny is🙄 https://t...  1398251577438138370
# 3  #NCTDREAM #NCT2020 nct dream hot sauce comebac...  1398215065010987011
# 4  #NCTDREAM #NCT2020 nct dream hot sauce comebac...  1398214968365903872
#
#                 userId  replyCount  retweetCount  likeCount  quoteCount  \
# 0  1398035707843821571           0             0          0           0
# 1  1394323475213570054           1             0          1           1
# 2  1022820266462703617           1             0          2           0
# 3  1334459256947449856           0             0          0           0
# 4  1334459256947449856           0             0          0           0
#
#                                                media  retweetedTweet  \
# 0                                               None             NaN
# 1                                               None             NaN
# 2  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 3  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 4  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
#
#   quotedTweet mentionedUsers lang
# 0        None           None   es
# 1        None           None   pt
# 2        None           None   en
# 3        None           None   en
# 4        None           None   en

# %%
#convert to dataframe, drop duplicates, keep only english tweets
tweets = pd.DataFrame(tweets)
tweets.drop_duplicates(subset=['tweetId'], inplace=True)
print(tweets.shape)
# Out:
# (100, 13)

# %%
#work required
tweets = tweets[tweets.lang =='en']

# %%
tweets.head(5)
# Out:
#                        date  \
# 2 2021-05-28 12:15:28+00:00
# 3 2021-05-28 09:50:23+00:00
# 4 2021-05-28 09:50:00+00:00
# 5 2021-05-28 09:49:35+00:00
# 6 2021-05-28 09:17:07+00:00
#
#                                      renderedContent              tweetId  \
# 2  #nctdisband look how fine johnny is🙄 https://t...  1398251577438138370
# 3  #NCTDREAM #NCT2020 nct dream hot sauce comebac...  1398215065010987011
# 4  #NCTDREAM #NCT2020 nct dream hot sauce comebac...  1398214968365903872
# 5  #NCTDREAM #NCT2020 nct dream hot sauce comebac...  1398214862786813952
# 6  I JUST STREAMED BITTERSWEET THEN THIS HASHTAG ...  1398206693620686848
#
#                 userId  replyCount  retweetCount  likeCount  quoteCount  \
# 2  1022820266462703617           1             0          2           0
# 3  1334459256947449856           0             0          0           0
# 4  1334459256947449856           0             0          0           0
# 5  1334459256947449856           0             0          0           0
# 6  1316582620289880064           0             0          0           0
#
#                                                media  retweetedTweet  \
# 2  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 3  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 4  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 5  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 6                                               None             NaN
#
#   quotedTweet mentionedUsers lang
# 2        None           None   en
# 3        None           None   en
# 4        None           None   en
# 5        None           None   en
# 6        None           None   en

# %%
tweets.to_csv('tag1.csv')
